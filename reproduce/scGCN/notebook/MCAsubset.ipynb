# %%
import os
from os.path import join
from pathlib import Path
cur_dir = Path(os.getcwd())
par_dir = cur_dir.parent.absolute()

import sys
import time
import numpy as np
import pickle as pkl
import tensorflow as tf
import scipy.sparse as sps

sys.path.append(str(par_dir))
from utils import *
from tensorflow.python.saved_model import tag_constants
from models import scGCN
# sys.stdout = open(str(cur_dir.joinpath('PBMC_lr=0.05_eps=50_outputs.txt')), "w")

import warnings
warnings.filterwarnings("ignore")
#' del_all_flags(FLAGS)

# Set random seed
seed = 123
np.random.seed(seed)
tf.compat.v1.set_random_seed(seed)
tf.set_random_seed(seed)

# %%
# Settings
exp_id = 'MCAsubset'
flags = tf.app.flags
FLAGS = flags.FLAGS
flags.DEFINE_string('f', '', 'kernel')  # to run in jupyter kernels
flags.DEFINE_string('dataset', join(str(par_dir), f'input/{exp_id}'), 'data dir')
flags.DEFINE_string('output', join(str(cur_dir), f'{exp_id}_results'), 'predicted results')
flags.DEFINE_bool('graph', True, 'select the optional graph.')
flags.DEFINE_string('model', 'scGCN','Model string.') 
flags.DEFINE_float('learning_rate', 0.05, 'Initial learning rate.')
flags.DEFINE_integer('epochs', 200, 'Number of epochs to train.')
flags.DEFINE_integer('hidden1', 32, 'Number of units in hidden layer 1.')
#flags.DEFINE_integer('hidden2', 32, 'Number of units in hidden layer 2.')
flags.DEFINE_float('dropout', 0, 'Dropout rate (1 - keep probability).')
flags.DEFINE_float('weight_decay', 0,
                   'Weight for L2 loss on embedding matrix.')
flags.DEFINE_integer('early_stopping', 10,
                     'Tolerance for early stopping (# of epochs).')
flags.DEFINE_integer('max_degree', 3, 'Maximum Chebyshev polynomial degree.')

# output flow
# sys.stdout = open(str(cur_dir.joinpath(f'{exp_id}_outputs.txt')), "w")

# %%
# Load data
adj, features, labels_binary_train, labels_binary_val, labels_binary_test, train_mask, pred_mask, val_mask, test_mask, new_label, true_label, index_guide = load_data(
    FLAGS.dataset,rgraph=FLAGS.graph)

support = [preprocess_adj(adj)]
num_supports = 1
model_func = scGCN

# Define placeholders
placeholders = {
    'support':
    [tf.sparse_placeholder(tf.float32) for _ in range(num_supports)],
    'features':
    tf.sparse_placeholder(tf.float32,
                          shape=tf.constant(features[2], dtype=tf.int64)),
    'labels':
    tf.placeholder(tf.float32, shape=(None, labels_binary_train.shape[1])),
    'labels_mask':
    tf.placeholder(tf.int32),
    'dropout':
    tf.placeholder_with_default(0., shape=()),
    'num_features_nonzero':
    tf.placeholder(tf.int32)  # helper variable for sparse dropout
}

# Create model
model = model_func(placeholders, input_dim=features[2][1], logging=True)

# Define model evaluation function
def evaluate(features, support, labels, mask, placeholders):
    t_test = time.time()
    feed_dict_val = construct_feed_dict(features, support, labels, mask,
                                        placeholders)
    outs_val = sess.run([model.loss, model.accuracy], feed_dict=feed_dict_val)
    return outs_val[0], outs_val[1], (time.time() - t_test)
# Out:
# load data succesfully....
# tr.shape=(73527, 2000), va.shape=(1781, 2000), te.shape=(1981, 2000)
# Constructing adjaceny graph
# assign input coordinatly....
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/models.py:94: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/models.py:40: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/utils.py:304: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/layers.py:68: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/layers.py:26: The name tf.sparse_retain is deprecated. Please use tf.sparse.retain instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/layers.py:33: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/layers.py:107: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/models.py:51: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/models.py:51: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/yxh/gitrepo/multi-omics/scGCN/scGCN/utils.py:275: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# Initialize session
sess = tf.Session()
# Init variables
sess.run(tf.global_variables_initializer())

train_accuracy = []
train_loss = []
val_accuracy = []
val_loss = []
test_accuracy = []
test_loss = []

# Train model

#configurate checkpoint directory to save intermediate model training weights
saver = tf.train.Saver()
save_dir = str(cur_dir.joinpath(f'{exp_id}_checkpoints/'))
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

save_path = os.path.join(save_dir, 'best_validation')

for epoch in range(FLAGS.epochs):
    t = time.time()
    # Construct feed dictionary
    feed_dict = construct_feed_dict(features, support, labels_binary_train,
                                    train_mask, placeholders)
    feed_dict.update({placeholders['dropout']: FLAGS.dropout})
    # Training step
    outs = sess.run([model.opt_op, model.loss, model.accuracy],
                    feed_dict=feed_dict)
    train_accuracy.append(outs[2])
    train_loss.append(outs[1])
    # Validation
    cost, acc, duration = evaluate(features, support, labels_binary_val,
                                   val_mask, placeholders)
    val_loss.append(cost)
    val_accuracy.append(acc)
    test_cost, test_acc, test_duration = evaluate(features, support,
                                                  labels_binary_test,
                                                  test_mask, placeholders)
    test_accuracy.append(test_acc)
    test_loss.append(test_cost)
    saver.save(sess=sess, save_path=save_path)
    print("Epoch:", '%04d' % (epoch + 1), "train_loss=",
          "{:.5f}".format(outs[1]), "train_acc=", "{:.5f}".format(outs[2]),
          "val_loss=", "{:.5f}".format(cost), "val_acc=", "{:.5f}".format(acc),
          "time=", "{:.5f}".format(time.time() - t))
    if epoch > FLAGS.early_stopping and val_loss[-1] > np.mean(
            val_loss[-(FLAGS.early_stopping + 1):-1]):
        print("Early stopping...")
        break

print("Finished Training....")
# Out:
# Epoch: 0001 train_loss= 2.94427 train_acc= 0.03358 val_loss= 2.86516 val_acc= 0.66648 time= 6.38544
# Epoch: 0002 train_loss= 2.86554 train_acc= 0.66424 val_loss= 2.72943 val_acc= 0.66143 time= 6.44660
# Epoch: 0003 train_loss= 2.73029 train_acc= 0.66061 val_loss= 2.54553 val_acc= 0.64851 time= 6.47234
# Epoch: 0004 train_loss= 2.54708 train_acc= 0.64345 val_loss= 2.32672 val_acc= 0.60472 time= 5.88628
# Epoch: 0005 train_loss= 2.32885 train_acc= 0.60486 val_loss= 2.09561 val_acc= 0.60247 time= 5.91706
# Epoch: 0006 train_loss= 2.09824 train_acc= 0.60292 val_loss= 1.88636 val_acc= 0.60247 time= 5.71773
# Epoch: 0007 train_loss= 1.88931 train_acc= 0.60267 val_loss= 1.72323 val_acc= 0.60247 time= 6.34516
# Epoch: 0008 train_loss= 1.72638 train_acc= 0.60311 val_loss= 1.60330 val_acc= 0.60247 time= 6.09968
# Epoch: 0009 train_loss= 1.60665 train_acc= 0.60392 val_loss= 1.50121 val_acc= 0.60472 time= 6.00435
# Epoch: 0010 train_loss= 1.50500 train_acc= 0.60461 val_loss= 1.39831 val_acc= 0.60472 time= 5.72887
# Epoch: 0011 train_loss= 1.40272 train_acc= 0.60480 val_loss= 1.29239 val_acc= 0.60472 time= 5.84241
# Epoch: 0012 train_loss= 1.29747 train_acc= 0.60499 val_loss= 1.18446 val_acc= 0.60696 time= 5.93474
# Epoch: 0013 train_loss= 1.19029 train_acc= 0.60624 val_loss= 1.07815 val_acc= 0.68332 time= 5.77573
# Epoch: 0014 train_loss= 1.08489 train_acc= 0.68416 val_loss= 0.98070 val_acc= 0.76530 time= 6.12266
# Epoch: 0015 train_loss= 0.98852 train_acc= 0.76447 val_loss= 0.89582 val_acc= 0.81190 time= 5.75811
# Epoch: 0016 train_loss= 0.90473 train_acc= 0.81264 val_loss= 0.82228 val_acc= 0.86244 time= 5.73558
# Epoch: 0017 train_loss= 0.83213 train_acc= 0.86062 val_loss= 0.75698 val_acc= 0.89332 time= 5.88007
# Epoch: 0018 train_loss= 0.76760 train_acc= 0.89082 val_loss= 0.69755 val_acc= 0.89669 time= 5.82864
# Epoch: 0019 train_loss= 0.70869 train_acc= 0.89520 val_loss= 0.64336 val_acc= 0.89725 time= 5.74821
# Epoch: 0020 train_loss= 0.65484 train_acc= 0.89558 val_loss= 0.59462 val_acc= 0.89557 time= 5.94120
# Epoch: 0021 train_loss= 0.60637 train_acc= 0.89552 val_loss= 0.55089 val_acc= 0.89557 time= 5.74435
# Epoch: 0022 train_loss= 0.56288 train_acc= 0.89627 val_loss= 0.51120 val_acc= 0.90286 time= 5.63310
# Epoch: 0023 train_loss= 0.52351 train_acc= 0.90416 val_loss= 0.47464 val_acc= 0.91522 time= 6.11676
# Epoch: 0024 train_loss= 0.48738 train_acc= 0.91481 val_loss= 0.44089 val_acc= 0.91690 time= 5.75633
# Epoch: 0025 train_loss= 0.45409 train_acc= 0.91569 val_loss= 0.40959 val_acc= 0.91690 time= 5.78954
# Epoch: 0026 train_loss= 0.42334 train_acc= 0.91619 val_loss= 0.38065 val_acc= 0.91802 time= 5.88232
# Epoch: 0027 train_loss= 0.39498 train_acc= 0.91656 val_loss= 0.35407 val_acc= 0.91690 time= 5.56061
# Epoch: 0028 train_loss= 0.36895 train_acc= 0.91769 val_loss= 0.32993 val_acc= 0.91802 time= 5.71556
# Epoch: 0029 train_loss= 0.34530 train_acc= 0.91894 val_loss= 0.30832 val_acc= 0.92196 time= 5.83183
# Epoch: 0030 train_loss= 0.32410 train_acc= 0.92107 val_loss= 0.28915 val_acc= 0.92196 time= 5.77744
# Epoch: 0031 train_loss= 0.30526 train_acc= 0.92201 val_loss= 0.27213 val_acc= 0.92252 time= 5.99364
# Epoch: 0032 train_loss= 0.28850 train_acc= 0.92220 val_loss= 0.25687 val_acc= 0.92196 time= 5.83619
# Epoch: 0033 train_loss= 0.27345 train_acc= 0.92314 val_loss= 0.24305 val_acc= 0.92532 time= 5.70457
# Epoch: 0034 train_loss= 0.25984 train_acc= 0.92665 val_loss= 0.23050 val_acc= 0.93094 time= 5.85980
# Epoch: 0035 train_loss= 0.24748 train_acc= 0.93385 val_loss= 0.21905 val_acc= 0.93712 time= 6.31251
# Epoch: 0036 train_loss= 0.23625 train_acc= 0.93943 val_loss= 0.20856 val_acc= 0.94105 time= 5.87436
# Epoch: 0037 train_loss= 0.22599 train_acc= 0.94400 val_loss= 0.19890 val_acc= 0.94554 time= 5.83608
# Epoch: 0038 train_loss= 0.21654 train_acc= 0.94669 val_loss= 0.18995 val_acc= 0.94722 time= 6.12088
# Epoch: 0039 train_loss= 0.20782 train_acc= 0.94807 val_loss= 0.18167 val_acc= 0.94891 time= 5.80557
# Epoch: 0040 train_loss= 0.19974 train_acc= 0.94933 val_loss= 0.17401 val_acc= 0.94947 time= 5.91552
# Epoch: 0041 train_loss= 0.19229 train_acc= 0.95001 val_loss= 0.16696 val_acc= 0.95340 time= 5.60888
# Epoch: 0042 train_loss= 0.18545 train_acc= 0.95146 val_loss= 0.16051 val_acc= 0.95452 time= 5.80006
# Epoch: 0043 train_loss= 0.17917 train_acc= 0.95440 val_loss= 0.15457 val_acc= 0.95621 time= 5.65778
# Epoch: 0044 train_loss= 0.17338 train_acc= 0.95546 val_loss= 0.14904 val_acc= 0.95733 time= 6.07457
# Epoch: 0045 train_loss= 0.16797 train_acc= 0.95559 val_loss= 0.14385 val_acc= 0.95733 time= 6.00478
# Epoch: 0046 train_loss= 0.16289 train_acc= 0.95584 val_loss= 0.13894 val_acc= 0.95789 time= 5.76715
# Epoch: 0047 train_loss= 0.15806 train_acc= 0.95653 val_loss= 0.13423 val_acc= 0.95901 time= 5.67851
# Epoch: 0048 train_loss= 0.15342 train_acc= 0.95753 val_loss= 0.12971 val_acc= 0.96070 time= 5.66587
# Epoch: 0049 train_loss= 0.14896 train_acc= 0.95853 val_loss= 0.12541 val_acc= 0.96070 time= 5.77996
# Epoch: 0050 train_loss= 0.14470 train_acc= 0.96016 val_loss= 0.12138 val_acc= 0.96126 time= 5.67422
# Epoch: 0051 train_loss= 0.14067 train_acc= 0.96116 val_loss= 0.11759 val_acc= 0.96350 time= 5.63984
# Epoch: 0052 train_loss= 0.13690 train_acc= 0.96229 val_loss= 0.11405 val_acc= 0.96575 time= 5.76588
# Epoch: 0053 train_loss= 0.13336 train_acc= 0.96367 val_loss= 0.11071 val_acc= 0.96912 time= 5.67934
# Epoch: 0054 train_loss= 0.13001 train_acc= 0.96492 val_loss= 0.10753 val_acc= 0.97024 time= 5.90590
# Epoch: 0055 train_loss= 0.12680 train_acc= 0.96661 val_loss= 0.10450 val_acc= 0.97137 time= 5.76436
# Epoch: 0056 train_loss= 0.12370 train_acc= 0.96768 val_loss= 0.10160 val_acc= 0.97193 time= 5.79475
# Epoch: 0057 train_loss= 0.12073 train_acc= 0.96868 val_loss= 0.09885 val_acc= 0.97249 time= 5.66192
# Epoch: 0058 train_loss= 0.11790 train_acc= 0.96900 val_loss= 0.09628 val_acc= 0.97361 time= 5.78052
# Epoch: 0059 train_loss= 0.11520 train_acc= 0.96943 val_loss= 0.09389 val_acc= 0.97417 time= 5.72059
# Epoch: 0060 train_loss= 0.11264 train_acc= 0.96962 val_loss= 0.09166 val_acc= 0.97417 time= 5.78989
# Epoch: 0061 train_loss= 0.11023 train_acc= 0.96975 val_loss= 0.08958 val_acc= 0.97417 time= 5.68900
# Epoch: 0062 train_loss= 0.10796 train_acc= 0.97000 val_loss= 0.08766 val_acc= 0.97417 time= 5.66756
# Epoch: 0063 train_loss= 0.10583 train_acc= 0.97062 val_loss= 0.08586 val_acc= 0.97530 time= 5.78797
# Epoch: 0064 train_loss= 0.10382 train_acc= 0.97113 val_loss= 0.08417 val_acc= 0.97530 time= 5.85498
# Epoch: 0065 train_loss= 0.10191 train_acc= 0.97150 val_loss= 0.08257 val_acc= 0.97642 time= 5.83060
# Epoch: 0066 train_loss= 0.10007 train_acc= 0.97194 val_loss= 0.08106 val_acc= 0.97754 time= 5.79964
# Epoch: 0067 train_loss= 0.09830 train_acc= 0.97238 val_loss= 0.07965 val_acc= 0.97810 time= 5.59075
# Epoch: 0068 train_loss= 0.09662 train_acc= 0.97288 val_loss= 0.07832 val_acc= 0.97810 time= 5.72428
# Epoch: 0069 train_loss= 0.09501 train_acc= 0.97319 val_loss= 0.07705 val_acc= 0.97866 time= 5.64131
# Epoch: 0070 train_loss= 0.09345 train_acc= 0.97376 val_loss= 0.07583 val_acc= 0.97979 time= 5.75923
# Epoch: 0071 train_loss= 0.09193 train_acc= 0.97407 val_loss= 0.07464 val_acc= 0.97979 time= 5.64582
# Epoch: 0072 train_loss= 0.09044 train_acc= 0.97432 val_loss= 0.07350 val_acc= 0.98035 time= 5.80792
# Epoch: 0073 train_loss= 0.08900 train_acc= 0.97476 val_loss= 0.07243 val_acc= 0.98035 time= 5.67939
# Epoch: 0074 train_loss= 0.08760 train_acc= 0.97488 val_loss= 0.07142 val_acc= 0.98091 time= 5.68018
# Epoch: 0075 train_loss= 0.08625 train_acc= 0.97501 val_loss= 0.07047 val_acc= 0.98091 time= 6.00014
# Epoch: 0076 train_loss= 0.08494 train_acc= 0.97495 val_loss= 0.06958 val_acc= 0.98091 time= 6.03158
# Epoch: 0077 train_loss= 0.08367 train_acc= 0.97513 val_loss= 0.06875 val_acc= 0.98091 time= 5.70799
# Epoch: 0078 train_loss= 0.08243 train_acc= 0.97526 val_loss= 0.06795 val_acc= 0.98091 time= 5.61158
# Epoch: 0079 train_loss= 0.08123 train_acc= 0.97551 val_loss= 0.06717 val_acc= 0.98091 time= 5.74693
# Epoch: 0080 train_loss= 0.08004 train_acc= 0.97589 val_loss= 0.06642 val_acc= 0.98147 time= 5.67405
# Epoch: 0081 train_loss= 0.07888 train_acc= 0.97620 val_loss= 0.06568 val_acc= 0.98091 time= 5.58704
# Epoch: 0082 train_loss= 0.07775 train_acc= 0.97676 val_loss= 0.06498 val_acc= 0.98091 time= 5.63827
# Epoch: 0083 train_loss= 0.07664 train_acc= 0.97708 val_loss= 0.06432 val_acc= 0.98091 time= 5.59781
# Epoch: 0084 train_loss= 0.07556 train_acc= 0.97739 val_loss= 0.06369 val_acc= 0.98091 time= 5.95206
# Epoch: 0085 train_loss= 0.07451 train_acc= 0.97745 val_loss= 0.06309 val_acc= 0.98091 time= 5.75830
# Epoch: 0086 train_loss= 0.07348 train_acc= 0.97789 val_loss= 0.06253 val_acc= 0.98091 time= 5.63914
# Epoch: 0087 train_loss= 0.07247 train_acc= 0.97814 val_loss= 0.06199 val_acc= 0.98091 time= 5.81572
# Epoch: 0088 train_loss= 0.07149 train_acc= 0.97820 val_loss= 0.06146 val_acc= 0.98091 time= 5.77399
# Epoch: 0089 train_loss= 0.07054 train_acc= 0.97864 val_loss= 0.06094 val_acc= 0.98147 time= 5.71017
# Epoch: 0090 train_loss= 0.06960 train_acc= 0.97933 val_loss= 0.06043 val_acc= 0.98147 time= 6.01938
# Epoch: 0091 train_loss= 0.06868 train_acc= 0.97964 val_loss= 0.05992 val_acc= 0.98147 time= 5.64663
# Epoch: 0092 train_loss= 0.06777 train_acc= 0.98015 val_loss= 0.05942 val_acc= 0.98203 time= 5.67595
# Epoch: 0093 train_loss= 0.06689 train_acc= 0.98071 val_loss= 0.05895 val_acc= 0.98203 time= 5.93919
# Epoch: 0094 train_loss= 0.06602 train_acc= 0.98121 val_loss= 0.05850 val_acc= 0.98316 time= 5.60418
# Epoch: 0095 train_loss= 0.06516 train_acc= 0.98202 val_loss= 0.05808 val_acc= 0.98316 time= 5.71833
# Epoch: 0096 train_loss= 0.06432 train_acc= 0.98265 val_loss= 0.05768 val_acc= 0.98316 time= 5.81847
# Epoch: 0097 train_loss= 0.06350 train_acc= 0.98284 val_loss= 0.05729 val_acc= 0.98316 time= 5.77178
# Epoch: 0098 train_loss= 0.06268 train_acc= 0.98309 val_loss= 0.05690 val_acc= 0.98316 time= 5.76750
# Epoch: 0099 train_loss= 0.06189 train_acc= 0.98353 val_loss= 0.05651 val_acc= 0.98316 time= 5.76752
# Epoch: 0100 train_loss= 0.06110 train_acc= 0.98403 val_loss= 0.05613 val_acc= 0.98316 time= 5.67739
# Epoch: 0101 train_loss= 0.06033 train_acc= 0.98466 val_loss= 0.05577 val_acc= 0.98316 time= 5.64537
# Epoch: 0102 train_loss= 0.05958 train_acc= 0.98484 val_loss= 0.05543 val_acc= 0.98260 time= 5.91367
# Epoch: 0103 train_loss= 0.05883 train_acc= 0.98503 val_loss= 0.05510 val_acc= 0.98260 time= 5.72855
# Epoch: 0104 train_loss= 0.05810 train_acc= 0.98553 val_loss= 0.05478 val_acc= 0.98203 time= 6.42218
# Epoch: 0105 train_loss= 0.05737 train_acc= 0.98566 val_loss= 0.05447 val_acc= 0.98203 time= 5.86920
# Epoch: 0106 train_loss= 0.05666 train_acc= 0.98610 val_loss= 0.05415 val_acc= 0.98203 time= 6.12592
# Epoch: 0107 train_loss= 0.05596 train_acc= 0.98616 val_loss= 0.05384 val_acc= 0.98203 time= 5.87188
# Epoch: 0108 train_loss= 0.05526 train_acc= 0.98660 val_loss= 0.05353 val_acc= 0.98260 time= 5.84254
# Epoch: 0109 train_loss= 0.05458 train_acc= 0.98666 val_loss= 0.05324 val_acc= 0.98316 time= 5.86989
# Epoch: 0110 train_loss= 0.05391 train_acc= 0.98691 val_loss= 0.05297 val_acc= 0.98372 time= 5.71964
# Epoch: 0111 train_loss= 0.05324 train_acc= 0.98710 val_loss= 0.05270 val_acc= 0.98372 time= 5.84967
# Epoch: 0112 train_loss= 0.05259 train_acc= 0.98729 val_loss= 0.05245 val_acc= 0.98372 time= 5.81348
# Epoch: 0113 train_loss= 0.05194 train_acc= 0.98766 val_loss= 0.05221 val_acc= 0.98372 time= 6.05643
# Epoch: 0114 train_loss= 0.05131 train_acc= 0.98785 val_loss= 0.05196 val_acc= 0.98316 time= 6.07121
# Epoch: 0115 train_loss= 0.05068 train_acc= 0.98791 val_loss= 0.05172 val_acc= 0.98316 time= 5.88534
# Epoch: 0116 train_loss= 0.05006 train_acc= 0.98804 val_loss= 0.05150 val_acc= 0.98316 time= 5.63095
# Epoch: 0117 train_loss= 0.04945 train_acc= 0.98829 val_loss= 0.05128 val_acc= 0.98316 time= 5.76513
# Epoch: 0118 train_loss= 0.04884 train_acc= 0.98835 val_loss= 0.05108 val_acc= 0.98316 time= 5.82484
# Epoch: 0119 train_loss= 0.04824 train_acc= 0.98848 val_loss= 0.05088 val_acc= 0.98372 time= 5.96131
# Epoch: 0120 train_loss= 0.04766 train_acc= 0.98866 val_loss= 0.05070 val_acc= 0.98372 time= 5.79964
# Epoch: 0121 train_loss= 0.04708 train_acc= 0.98885 val_loss= 0.05051 val_acc= 0.98428 time= 5.68180
# Epoch: 0122 train_loss= 0.04650 train_acc= 0.98898 val_loss= 0.05033 val_acc= 0.98428 time= 5.91351
# Epoch: 0123 train_loss= 0.04594 train_acc= 0.98917 val_loss= 0.05015 val_acc= 0.98428 time= 5.74240
# Epoch: 0124 train_loss= 0.04538 train_acc= 0.98935 val_loss= 0.04998 val_acc= 0.98484 time= 5.64426
# Epoch: 0125 train_loss= 0.04483 train_acc= 0.98935 val_loss= 0.04983 val_acc= 0.98596 time= 5.78880
# Epoch: 0126 train_loss= 0.04428 train_acc= 0.98942 val_loss= 0.04968 val_acc= 0.98596 time= 5.91926
# Epoch: 0127 train_loss= 0.04374 train_acc= 0.98942 val_loss= 0.04953 val_acc= 0.98596 time= 5.66314
# Epoch: 0128 train_loss= 0.04321 train_acc= 0.98954 val_loss= 0.04938 val_acc= 0.98596 time= 5.65638
# Epoch: 0129 train_loss= 0.04269 train_acc= 0.98960 val_loss= 0.04924 val_acc= 0.98596 time= 5.85790
# Epoch: 0130 train_loss= 0.04217 train_acc= 0.98979 val_loss= 0.04911 val_acc= 0.98596 time= 5.76413
# Epoch: 0131 train_loss= 0.04166 train_acc= 0.98985 val_loss= 0.04898 val_acc= 0.98596 time= 5.54658
# Epoch: 0132 train_loss= 0.04116 train_acc= 0.99011 val_loss= 0.04887 val_acc= 0.98596 time= 5.97268
# Epoch: 0133 train_loss= 0.04067 train_acc= 0.99011 val_loss= 0.04875 val_acc= 0.98653 time= 6.61424
# Epoch: 0134 train_loss= 0.04018 train_acc= 0.99011 val_loss= 0.04864 val_acc= 0.98653 time= 5.87268
# Epoch: 0135 train_loss= 0.03969 train_acc= 0.99023 val_loss= 0.04854 val_acc= 0.98653 time= 5.69012
# Epoch: 0136 train_loss= 0.03922 train_acc= 0.99029 val_loss= 0.04843 val_acc= 0.98653 time= 5.99744
# Epoch: 0137 train_loss= 0.03875 train_acc= 0.99036 val_loss= 0.04834 val_acc= 0.98709 time= 5.89216
# Epoch: 0138 train_loss= 0.03828 train_acc= 0.99042 val_loss= 0.04825 val_acc= 0.98709 time= 5.72705
# Epoch: 0139 train_loss= 0.03783 train_acc= 0.99042 val_loss= 0.04816 val_acc= 0.98709 time= 5.83152
# Epoch: 0140 train_loss= 0.03737 train_acc= 0.99061 val_loss= 0.04808 val_acc= 0.98709 time= 5.92710
# Epoch: 0141 train_loss= 0.03693 train_acc= 0.99086 val_loss= 0.04800 val_acc= 0.98709 time= 5.69980
# Epoch: 0142 train_loss= 0.03648 train_acc= 0.99092 val_loss= 0.04792 val_acc= 0.98653 time= 5.65580
# Epoch: 0143 train_loss= 0.03605 train_acc= 0.99111 val_loss= 0.04784 val_acc= 0.98653 time= 5.79473
# Epoch: 0144 train_loss= 0.03561 train_acc= 0.99117 val_loss= 0.04777 val_acc= 0.98709 time= 5.70889
# Epoch: 0145 train_loss= 0.03519 train_acc= 0.99123 val_loss= 0.04771 val_acc= 0.98765 time= 5.92030
# Epoch: 0146 train_loss= 0.03476 train_acc= 0.99142 val_loss= 0.04764 val_acc= 0.98765 time= 5.75001
# Epoch: 0147 train_loss= 0.03434 train_acc= 0.99155 val_loss= 0.04757 val_acc= 0.98765 time= 5.77399
# Epoch: 0148 train_loss= 0.03393 train_acc= 0.99161 val_loss= 0.04750 val_acc= 0.98709 time= 5.65595
# Epoch: 0149 train_loss= 0.03352 train_acc= 0.99167 val_loss= 0.04742 val_acc= 0.98709 time= 5.66368
# Epoch: 0150 train_loss= 0.03311 train_acc= 0.99198 val_loss= 0.04735 val_acc= 0.98709 time= 5.95384
# Epoch: 0151 train_loss= 0.03271 train_acc= 0.99211 val_loss= 0.04729 val_acc= 0.98709 time= 5.69126
# Epoch: 0152 train_loss= 0.03232 train_acc= 0.99224 val_loss= 0.04723 val_acc= 0.98709 time= 5.69546
# Epoch: 0153 train_loss= 0.03192 train_acc= 0.99261 val_loss= 0.04717 val_acc= 0.98765 time= 5.74512
# Epoch: 0154 train_loss= 0.03154 train_acc= 0.99274 val_loss= 0.04711 val_acc= 0.98765 time= 5.72338
# Epoch: 0155 train_loss= 0.03115 train_acc= 0.99274 val_loss= 0.04705 val_acc= 0.98821 time= 5.80055
# Epoch: 0156 train_loss= 0.03077 train_acc= 0.99274 val_loss= 0.04699 val_acc= 0.98821 time= 5.83296
# Epoch: 0157 train_loss= 0.03040 train_acc= 0.99280 val_loss= 0.04693 val_acc= 0.98821 time= 5.89057
# Epoch: 0158 train_loss= 0.03003 train_acc= 0.99299 val_loss= 0.04688 val_acc= 0.98821 time= 5.82069
# Epoch: 0159 train_loss= 0.02966 train_acc= 0.99305 val_loss= 0.04683 val_acc= 0.98821 time= 5.61893
# Epoch: 0160 train_loss= 0.02930 train_acc= 0.99317 val_loss= 0.04678 val_acc= 0.98821 time= 5.78085
# Epoch: 0161 train_loss= 0.02894 train_acc= 0.99324 val_loss= 0.04672 val_acc= 0.98821 time= 5.77431
# Epoch: 0162 train_loss= 0.02859 train_acc= 0.99336 val_loss= 0.04667 val_acc= 0.98821 time= 5.85478
# Epoch: 0163 train_loss= 0.02824 train_acc= 0.99349 val_loss= 0.04662 val_acc= 0.98821 time= 5.70304
# Epoch: 0164 train_loss= 0.02790 train_acc= 0.99361 val_loss= 0.04657 val_acc= 0.98821 time= 5.88143
# Epoch: 0165 train_loss= 0.02756 train_acc= 0.99368 val_loss= 0.04653 val_acc= 0.98821 time= 5.75399
# Epoch: 0166 train_loss= 0.02722 train_acc= 0.99374 val_loss= 0.04648 val_acc= 0.98821 time= 5.76689
# Epoch: 0167 train_loss= 0.02689 train_acc= 0.99374 val_loss= 0.04643 val_acc= 0.98821 time= 5.67782
# Epoch: 0168 train_loss= 0.02656 train_acc= 0.99386 val_loss= 0.04640 val_acc= 0.98821 time= 5.66582
# Epoch: 0169 train_loss= 0.02624 train_acc= 0.99399 val_loss= 0.04637 val_acc= 0.98821 time= 5.63216
# Epoch: 0170 train_loss= 0.02592 train_acc= 0.99411 val_loss= 0.04633 val_acc= 0.98821 time= 5.59491
# Epoch: 0171 train_loss= 0.02560 train_acc= 0.99411 val_loss= 0.04629 val_acc= 0.98821 time= 5.59429
# Epoch: 0172 train_loss= 0.02529 train_acc= 0.99418 val_loss= 0.04626 val_acc= 0.98821 time= 5.73519
# Epoch: 0173 train_loss= 0.02498 train_acc= 0.99424 val_loss= 0.04622 val_acc= 0.98821 time= 5.79012
# Epoch: 0174 train_loss= 0.02468 train_acc= 0.99424 val_loss= 0.04619 val_acc= 0.98821 time= 5.64715
# Epoch: 0175 train_loss= 0.02439 train_acc= 0.99443 val_loss= 0.04615 val_acc= 0.98821 time= 5.77820
# Epoch: 0176 train_loss= 0.02409 train_acc= 0.99443 val_loss= 0.04611 val_acc= 0.98821 time= 6.20001
# Epoch: 0177 train_loss= 0.02380 train_acc= 0.99468 val_loss= 0.04608 val_acc= 0.98821 time= 5.64330
# Epoch: 0178 train_loss= 0.02352 train_acc= 0.99468 val_loss= 0.04605 val_acc= 0.98821 time= 5.65919
# Epoch: 0179 train_loss= 0.02323 train_acc= 0.99474 val_loss= 0.04602 val_acc= 0.98821 time= 5.81466
# Epoch: 0180 train_loss= 0.02295 train_acc= 0.99487 val_loss= 0.04600 val_acc= 0.98821 time= 5.61922
# Epoch: 0181 train_loss= 0.02268 train_acc= 0.99505 val_loss= 0.04597 val_acc= 0.98821 time= 5.78762
# Epoch: 0182 train_loss= 0.02241 train_acc= 0.99512 val_loss= 0.04595 val_acc= 0.98821 time= 5.72110
# Epoch: 0183 train_loss= 0.02214 train_acc= 0.99518 val_loss= 0.04594 val_acc= 0.98821 time= 5.68522
# Epoch: 0184 train_loss= 0.02187 train_acc= 0.99524 val_loss= 0.04592 val_acc= 0.98765 time= 5.85729
# Epoch: 0185 train_loss= 0.02161 train_acc= 0.99530 val_loss= 0.04590 val_acc= 0.98821 time= 5.70856
# Epoch: 0186 train_loss= 0.02135 train_acc= 0.99543 val_loss= 0.04588 val_acc= 0.98821 time= 5.90145
# Epoch: 0187 train_loss= 0.02110 train_acc= 0.99549 val_loss= 0.04586 val_acc= 0.98821 time= 5.58743
# Epoch: 0188 train_loss= 0.02085 train_acc= 0.99549 val_loss= 0.04584 val_acc= 0.98821 time= 5.60528
# Epoch: 0189 train_loss= 0.02060 train_acc= 0.99556 val_loss= 0.04582 val_acc= 0.98821 time= 5.58393
# Epoch: 0190 train_loss= 0.02036 train_acc= 0.99562 val_loss= 0.04582 val_acc= 0.98765 time= 5.60050
# Epoch: 0191 train_loss= 0.02012 train_acc= 0.99574 val_loss= 0.04582 val_acc= 0.98765 time= 5.57641
# Epoch: 0192 train_loss= 0.01988 train_acc= 0.99587 val_loss= 0.04581 val_acc= 0.98765 time= 5.57759
# Epoch: 0193 train_loss= 0.01964 train_acc= 0.99587 val_loss= 0.04580 val_acc= 0.98765 time= 5.59474
# Epoch: 0194 train_loss= 0.01941 train_acc= 0.99593 val_loss= 0.04580 val_acc= 0.98765 time= 5.63356
# Epoch: 0195 train_loss= 0.01918 train_acc= 0.99606 val_loss= 0.04580 val_acc= 0.98765 time= 5.61353
# Epoch: 0196 train_loss= 0.01896 train_acc= 0.99612 val_loss= 0.04581 val_acc= 0.98765 time= 5.56516
# Epoch: 0197 train_loss= 0.01874 train_acc= 0.99624 val_loss= 0.04581 val_acc= 0.98765 time= 5.59694
# Epoch: 0198 train_loss= 0.01852 train_acc= 0.99637 val_loss= 0.04582 val_acc= 0.98765 time= 5.62422
# Early stopping...
# Finished Training....

# %%
all_mask = np.array([True] * len(train_mask))
labels_binary_all = new_label

feed_dict_all = construct_feed_dict(features, support, labels_binary_all,
                                    all_mask, placeholders)
feed_dict_all.update({placeholders['dropout']: FLAGS.dropout})

activation_output = sess.run(model.activations, feed_dict=feed_dict_all)[1]
predict_output = sess.run(model.outputs, feed_dict=feed_dict_all)

#' accuracy on all masks
ab = sess.run(tf.nn.softmax(predict_output))
all_prediction = sess.run(
    tf.equal(sess.run(tf.argmax(ab, 1)),
             sess.run(tf.argmax(labels_binary_all.astype('int32'), 1))))

#' accuracy on prediction masks 
acc_train = np.sum(all_prediction[train_mask]) / np.sum(train_mask)
acc_test = np.sum(all_prediction[test_mask]) / np.sum(test_mask)
acc_val = np.sum(all_prediction[val_mask]) / np.sum(val_mask)
acc_pred = np.sum(all_prediction[pred_mask]) / np.sum(pred_mask)
print('Checking train/test/val set accuracy: {}, {}, {}'.format(
    acc_train, acc_test, acc_val))
print('Checking pred set accuracy: {}'.format(acc_pred))
# Out:
# Checking train/test/val set accuracy: 0.9964294662991732, 0.9878849066128218, 0.9876473891072431
# Checking pred set accuracy: 0.7436895227837326

# %%
acc_pred, acc_train, acc_val
# Out:
# (0.7436895227837326, 0.9964294662991732, 0.9876473891072431)

# %%
pred_label = sess.run(tf.argmax(ab, 1))
pred_prob = sess.run(tf.reduce_max(ab, 1))
gt_label   = sess.run(tf.argmax(labels_binary_all.astype('float'), 1))
id2label = dict(zip(gt_label[pred_mask], true_label[pred_mask].to_numpy().ravel()))
pred_type = np.array([id2label[_] for _ in pred_label])

import scanpy as sc
adata = sc.AnnData(predict_output[pred_mask])
adata.obs['pred_type'] = pred_type[pred_mask]
adata.obs['cell_type'] = true_label[pred_mask].to_numpy().ravel()
adata.obs['pred_prob'] = pred_prob[pred_mask]

# %%
import umap

reducer = umap.UMAP(n_neighbors=15,
                    n_components=2,
                    metric="correlation",
                    n_epochs=None,
                    learning_rate=1.0,
                    min_dist=0.3,
                    spread=1.0,
                    set_op_mix_ratio=1.0,
                    local_connectivity=1,
                    repulsion_strength=1,
                    negative_sample_rate=5,
                    a=None,
                    b=None,
                    random_state=1234,
                    metric_kwds=None,
                    angular_rp_forest=False,
                    verbose=False)
embedding = reducer.fit_transform(adata.X)
adata.obsm["X_umap"] = embedding

sc.pl.umap(adata, color=['cell_type'])
# Out:
# ... storing 'pred_type' as categorical
# ... storing 'cell_type' as categorical

# %%
sc.pl.umap(adata, color=['cell_type', 'pred_type', 'pred_prob'])

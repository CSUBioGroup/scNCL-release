# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append("../")
from concerto_function5_3 import *
from sklearn.metrics import f1_score, accuracy_score
import numpy as np
import scanpy as sc
import scipy.sparse as sps
import matplotlib.pyplot as plt
from metrics import osr_evaluator

from os.path import join

# %%
#Select an available GPU to run on a multi-GPU computer or you can run it directly on the CPU without executing this cell
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = '1' 
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
exp_id = 'MCAOS'
data_root = '/home/yanxh/data/MCA/scjoint/data_atlas'

adata_rna = sc.read_h5ad('/home/yanxh/gitrepo/Portal-main/cache/adata_rna_facs.h5ad')
adata_atac = sc.read_h5ad(join(data_root, 'adata_atac_cache.h5ad'))

batch_key = 'domain'
type_key = 'cell_type'

adata_rna, adata_atac
# Out:
# (AnnData object with n_obs × n_vars = 19726 × 15519
#      obs: 'cell_type', 'domain',
#  AnnData object with n_obs × n_vars = 81173 × 15519
#      obs: 'Unnamed: 0', 'cell_label', 'domain', 'cell_type')

# %%
adata_all = sc.concat([adata_rna, adata_atac])
adata_all
# Out:
# AnnData object with n_obs × n_vars = 100899 × 15519
#     obs: 'cell_type', 'domain'

# %% [markdown]
# # Preprocess

# %%
# filter cells, normalize_total, hvg(if), no scale
adata = preprocessing_rna(adata_all, 
                          min_features=0, 
                          n_top_features=None, 
                          is_hvg=False, 
                          batch_key=batch_key)

adata_ref = adata[adata.obs[batch_key] == 'rna_facs']
adata_query = adata[adata.obs[batch_key] == 'atac']

shr_mask = np.in1d(adata_query.obs[type_key], adata_ref.obs[type_key].unique())
atac_lab = np.array(adata_query.obs[type_key].values)

save_path = './'
# if not os.path.exists(save_path):
#     os.makedirs(save_path)
# adata_ref.write_h5ad(save_path + 'adata_ref.h5ad')
# adata_query.write_h5ad(save_path + 'adata_query.h5ad')  # .tech=='indrop'
# Out:
# Processed dataset shape: (100899, 15519)

# %%
ref_tf_path = concerto_make_tfrecord_supervised(adata_ref, tf_path = save_path + f'tfrecord/{exp_id}/ref_tf/',
                                     batch_col_name = batch_key, label_col_name=type_key)
query_tf_path = concerto_make_tfrecord_supervised(adata_query, tf_path = save_path + f'tfrecord/{exp_id}/query_tf/',
                                     batch_col_name = batch_key, label_col_name=type_key)
# Out:
# counter: 10000 shape: (15519,), batch: 0
# [1.e-05 1.e-05 1.e-05 ... 1.e-05 1.e-05 1.e-05]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  9.99999975e-06 9.99999975e-06]
# batchs:  ['rna_facs']
# counter: 10000 shape: (15519,), batch: 0
# [1.e-05 1.e-05 1.e-05 ... 1.e-05 1.e-05 1.e-05]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  9.99999975e-06 9.99999975e-06]
# batchs:  ['atac']
# counter: 20000 shape: (15519,), batch: 0
# [9.9999997e-06 9.9999997e-06 2.8683867e+00 ... 9.9999997e-06 9.9999997e-06
#  9.9999997e-06]
# [9.99999975e-06 9.99999975e-06 2.86838675e+00 ... 9.99999975e-06
#  9.99999975e-06 9.99999975e-06]
# batchs:  ['atac']
# counter: 30000 shape: (15519,), batch: 0
# [9.9999997e-06 9.9999997e-06 9.9999997e-06 ... 9.9999997e-06 1.3322642e+00
#  1.2836080e+00]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  1.33226418e+00 1.28360796e+00]
# batchs:  ['atac']
# counter: 40000 shape: (15519,), batch: 0
# [9.9999997e-06 9.9999997e-06 9.9999997e-06 ... 1.7124004e+00 9.9999997e-06
#  1.9744304e+00]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 1.71240044e+00
#  9.99999975e-06 1.97443044e+00]
# batchs:  ['atac']
# counter: 50000 shape: (15519,), batch: 0
# [1.e-05 1.e-05 1.e-05 ... 1.e-05 1.e-05 1.e-05]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  9.99999975e-06 9.99999975e-06]
# batchs:  ['atac']
# counter: 60000 shape: (15519,), batch: 0
# [9.9999997e-06 9.9999997e-06 9.9999997e-06 ... 9.9999997e-06 1.6672462e+00
#  1.3819668e-01]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  1.66724622e+00 1.38196677e-01]
# batchs:  ['atac']
# counter: 70000 shape: (15519,), batch: 0
# [9.9999997e-06 9.9999997e-06 9.9999997e-06 ... 9.9999997e-06 1.9520494e+00
#  2.7893891e+00]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  1.95204937e+00 2.78938913e+00]
# batchs:  ['atac']
# counter: 80000 shape: (15519,), batch: 0
# [1.e-05 1.e-05 1.e-05 ... 1.e-05 1.e-05 1.e-05]
# [9.99999975e-06 9.99999975e-06 9.99999975e-06 ... 9.99999975e-06
#  9.99999975e-06 9.99999975e-06]
# batchs:  ['atac']

# %%
# train (leave spleen out). If you don't want to train the model, you can just load our trained classifier's weight and test it directly.
weight_path = save_path + f'weight/{exp_id}/'
ref_tf_path = save_path + f'tfrecord/{exp_id}/ref_tf/'
query_tf_path = save_path + f'tfrecord/{exp_id}/query_tf/'

concerto_train_inter_supervised_uda2(ref_tf_path, query_tf_path, weight_path,
                                     super_parameters={'batch_size': 128, 'epoch_pretrain': 1,'epoch_classifier': 10, 'lr': 1e-4,'drop_rate': 0.1})
# Out:
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 1, step 5, simclr loss: 10.4962.
# Epoch 1, step 10, simclr loss: 10.1023.
# Epoch 1, step 15, simclr loss: 9.6408.
# Epoch 1, step 20, simclr loss: 9.1084.
# Epoch 1, step 25, simclr loss: 8.5713.
# Epoch 1, step 30, simclr loss: 8.0368.
# Epoch 1, step 35, simclr loss: 7.5131.
# Epoch 1, step 40, simclr loss: 6.9630.
# Epoch 1, step 45, simclr loss: 6.4614.
# Epoch 1, step 50, simclr loss: 5.9354.
# Epoch 1, step 55, simclr loss: 5.4701.
# Epoch 1, step 60, simclr loss: 4.9818.
# Epoch 1, step 65, simclr loss: 4.5394.
# Epoch 1, step 70, simclr loss: 4.1475.
# Epoch 1, step 75, simclr loss: 3.7763.
# Epoch 1, step 80, simclr loss: 3.4782.
# Epoch 1, step 85, simclr loss: 3.1817.
# Epoch 1, step 90, simclr loss: 2.9367.
# Epoch 1, step 95, simclr loss: 2.7166.
# Epoch 1, step 100, simclr loss: 2.5108.
# Epoch 1, step 105, simclr loss: 2.3213.
# Epoch 1, step 110, simclr loss: 2.1443.
# Epoch 1, step 115, simclr loss: 2.0020.
# Epoch 1, step 120, simclr loss: 1.8551.
# Epoch 1, step 125, simclr loss: 1.7235.
# Epoch 1, step 130, simclr loss: 1.6039.
# Epoch 1, step 135, simclr loss: 1.4960.
# Epoch 1, step 140, simclr loss: 1.3674.
# Epoch 1, step 145, simclr loss: 1.2642.
# Epoch 1, step 150, simclr loss: 1.1773.
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 0, step 5, train cls loss: 3.1942, train acc: 0.0891
# Epoch 0, step 10, train cls loss: 3.1883, train acc: 0.1164
# Epoch 0, step 15, train cls loss: 3.1748, train acc: 0.2172
# Epoch 0, step 20, train cls loss: 3.1591, train acc: 0.2684
# Epoch 0, step 25, train cls loss: 3.1488, train acc: 0.2947
# Epoch 0, step 30, train cls loss: 3.1166, train acc: 0.3385
# Epoch 0, step 35, train cls loss: 3.0969, train acc: 0.3429
# Epoch 0, step 40, train cls loss: 3.0515, train acc: 0.3674
# Epoch 0, step 45, train cls loss: 3.0239, train acc: 0.3523
# Epoch 0, step 50, train cls loss: 2.9347, train acc: 0.3656
# Epoch 0, step 55, train cls loss: 2.9135, train acc: 0.3658
# Epoch 0, step 60, train cls loss: 2.8571, train acc: 0.3650
# Epoch 0, step 65, train cls loss: 2.8081, train acc: 0.3689
# Epoch 0, step 70, train cls loss: 2.7390, train acc: 0.3798
# Epoch 0, step 75, train cls loss: 2.6942, train acc: 0.3876
# Epoch 0, step 80, train cls loss: 2.6504, train acc: 0.3896
# Epoch 0, step 85, train cls loss: 2.5992, train acc: 0.3966
# Epoch 0, step 90, train cls loss: 2.5558, train acc: 0.4103
# Epoch 0, step 95, train cls loss: 2.5255, train acc: 0.4145
# Epoch 0, step 100, train cls loss: 2.4663, train acc: 0.4335
# Epoch 0, step 105, train cls loss: 2.4184, train acc: 0.4452
# Epoch 0, step 110, train cls loss: 2.3639, train acc: 0.4589
# Epoch 0, step 115, train cls loss: 2.3118, train acc: 0.4728
# Epoch 0, step 120, train cls loss: 2.2890, train acc: 0.4765
# Epoch 0, step 125, train cls loss: 2.2786, train acc: 0.4762
# Epoch 0, step 130, train cls loss: 2.2902, train acc: 0.4682
# Epoch 0, step 135, train cls loss: 2.2561, train acc: 0.4815
# Epoch 0, step 140, train cls loss: 2.2563, train acc: 0.4825
# Epoch 0, step 145, train cls loss: 2.2287, train acc: 0.4891
# Epoch 0, step 150, train cls loss: 2.2173, train acc: 0.4886
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 1, step 5, train cls loss: 1.0298, train acc: 0.9125
# Epoch 1, step 10, train cls loss: 1.5572, train acc: 0.8062
# Epoch 1, step 15, train cls loss: 1.3242, train acc: 0.8401
# Epoch 1, step 20, train cls loss: 1.3920, train acc: 0.7848
# Epoch 1, step 25, train cls loss: 1.3388, train acc: 0.7731
# Epoch 1, step 30, train cls loss: 1.4300, train acc: 0.7109
# Epoch 1, step 35, train cls loss: 1.4690, train acc: 0.6801
# Epoch 1, step 40, train cls loss: 1.5087, train acc: 0.6695
# Epoch 1, step 45, train cls loss: 1.5158, train acc: 0.6644
# Epoch 1, step 50, train cls loss: 1.5519, train acc: 0.6602
# Epoch 1, step 55, train cls loss: 1.4988, train acc: 0.6800
# Epoch 1, step 60, train cls loss: 1.4923, train acc: 0.6805
# Epoch 1, step 65, train cls loss: 1.4657, train acc: 0.6913
# Epoch 1, step 70, train cls loss: 1.4485, train acc: 0.6949
# Epoch 1, step 75, train cls loss: 1.4191, train acc: 0.7071
# Epoch 1, step 80, train cls loss: 1.4125, train acc: 0.7064
# Epoch 1, step 85, train cls loss: 1.4034, train acc: 0.7066
# Epoch 1, step 90, train cls loss: 1.3875, train acc: 0.7098
# Epoch 1, step 95, train cls loss: 1.3602, train acc: 0.7184
# Epoch 1, step 100, train cls loss: 1.3646, train acc: 0.7187
# Epoch 1, step 105, train cls loss: 1.3548, train acc: 0.7223
# Epoch 1, step 110, train cls loss: 1.3289, train acc: 0.7326
# Epoch 1, step 115, train cls loss: 1.3477, train acc: 0.7336
# Epoch 1, step 120, train cls loss: 1.3455, train acc: 0.7326
# Epoch 1, step 125, train cls loss: 1.3300, train acc: 0.7366
# Epoch 1, step 130, train cls loss: 1.3026, train acc: 0.7457
# Epoch 1, step 135, train cls loss: 1.2894, train acc: 0.7494
# Epoch 1, step 140, train cls loss: 1.2681, train acc: 0.7563
# Epoch 1, step 145, train cls loss: 1.2653, train acc: 0.7548
# Epoch 1, step 150, train cls loss: 1.2489, train acc: 0.7585
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 2, step 5, train cls loss: 0.7273, train acc: 0.8969
# Epoch 2, step 10, train cls loss: 0.6892, train acc: 0.9148
# Epoch 2, step 15, train cls loss: 0.6528, train acc: 0.9339
# Epoch 2, step 20, train cls loss: 0.6812, train acc: 0.9234
# Epoch 2, step 25, train cls loss: 0.6984, train acc: 0.9197
# Epoch 2, step 30, train cls loss: 0.7053, train acc: 0.9206
# Epoch 2, step 35, train cls loss: 0.7335, train acc: 0.9096
# Epoch 2, step 40, train cls loss: 0.7739, train acc: 0.8980
# Epoch 2, step 45, train cls loss: 0.7823, train acc: 0.8983
# Epoch 2, step 50, train cls loss: 0.8455, train acc: 0.8806
# Epoch 2, step 55, train cls loss: 0.8498, train acc: 0.8821
# Epoch 2, step 60, train cls loss: 0.8509, train acc: 0.8845
# Epoch 2, step 65, train cls loss: 0.8415, train acc: 0.8865
# Epoch 2, step 70, train cls loss: 0.8492, train acc: 0.8843
# Epoch 2, step 75, train cls loss: 0.8701, train acc: 0.8777
# Epoch 2, step 80, train cls loss: 0.8634, train acc: 0.8794
# Epoch 2, step 85, train cls loss: 0.8586, train acc: 0.8803
# Epoch 2, step 90, train cls loss: 0.8536, train acc: 0.8806
# Epoch 2, step 95, train cls loss: 0.8461, train acc: 0.8832
# Epoch 2, step 100, train cls loss: 0.8388, train acc: 0.8863
# Epoch 2, step 105, train cls loss: 0.8319, train acc: 0.8893
# Epoch 2, step 110, train cls loss: 0.8242, train acc: 0.8916
# Epoch 2, step 115, train cls loss: 0.8258, train acc: 0.8906
# Epoch 2, step 120, train cls loss: 0.8186, train acc: 0.8933
# Epoch 2, step 125, train cls loss: 0.8313, train acc: 0.8905
# Epoch 2, step 130, train cls loss: 0.8232, train acc: 0.8932
# Epoch 2, step 135, train cls loss: 0.8273, train acc: 0.8929
# Epoch 2, step 140, train cls loss: 0.8237, train acc: 0.8940
# Epoch 2, step 145, train cls loss: 0.8189, train acc: 0.8954
# Epoch 2, step 150, train cls loss: 0.8083, train acc: 0.8984
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 3, step 5, train cls loss: 0.6031, train acc: 0.9641
# Epoch 3, step 10, train cls loss: 0.6302, train acc: 0.9594
# Epoch 3, step 15, train cls loss: 0.7100, train acc: 0.9286
# Epoch 3, step 20, train cls loss: 0.6695, train acc: 0.9375
# Epoch 3, step 25, train cls loss: 0.6590, train acc: 0.9378
# Epoch 3, step 30, train cls loss: 0.6501, train acc: 0.9406
# Epoch 3, step 35, train cls loss: 0.6324, train acc: 0.9453
# Epoch 3, step 40, train cls loss: 0.6211, train acc: 0.9498
# Epoch 3, step 45, train cls loss: 0.6202, train acc: 0.9502
# Epoch 3, step 50, train cls loss: 0.6074, train acc: 0.9531
# Epoch 3, step 55, train cls loss: 0.6096, train acc: 0.9506
# Epoch 3, step 60, train cls loss: 0.6101, train acc: 0.9505
# Epoch 3, step 65, train cls loss: 0.6169, train acc: 0.9460
# Epoch 3, step 70, train cls loss: 0.6219, train acc: 0.9460
# Epoch 3, step 75, train cls loss: 0.6606, train acc: 0.9365
# Epoch 3, step 80, train cls loss: 0.6559, train acc: 0.9372
# Epoch 3, step 85, train cls loss: 0.6554, train acc: 0.9368
# Epoch 3, step 90, train cls loss: 0.6454, train acc: 0.9399
# Epoch 3, step 95, train cls loss: 0.6469, train acc: 0.9396
# Epoch 3, step 100, train cls loss: 0.6616, train acc: 0.9343
# Epoch 3, step 105, train cls loss: 0.6560, train acc: 0.9361
# Epoch 3, step 110, train cls loss: 0.6576, train acc: 0.9369
# Epoch 3, step 115, train cls loss: 0.6614, train acc: 0.9372
# Epoch 3, step 120, train cls loss: 0.6612, train acc: 0.9379
# Epoch 3, step 125, train cls loss: 0.6644, train acc: 0.9371
# Epoch 3, step 130, train cls loss: 0.6615, train acc: 0.9380
# Epoch 3, step 135, train cls loss: 0.6618, train acc: 0.9378
# Epoch 3, step 140, train cls loss: 0.6595, train acc: 0.9390
# Epoch 3, step 145, train cls loss: 0.6559, train acc: 0.9402
# Epoch 3, step 150, train cls loss: 0.6526, train acc: 0.9407
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 4, step 5, train cls loss: 0.4907, train acc: 0.9844
# Epoch 4, step 10, train cls loss: 0.4851, train acc: 0.9875
# Epoch 4, step 15, train cls loss: 0.4975, train acc: 0.9839
# Epoch 4, step 20, train cls loss: 0.4972, train acc: 0.9848
# Epoch 4, step 25, train cls loss: 0.5090, train acc: 0.9800
# Epoch 4, step 30, train cls loss: 0.5172, train acc: 0.9776
# Epoch 4, step 35, train cls loss: 0.5210, train acc: 0.9777
# Epoch 4, step 40, train cls loss: 0.5252, train acc: 0.9762
# Epoch 4, step 45, train cls loss: 0.5299, train acc: 0.9759
# Epoch 4, step 50, train cls loss: 0.5258, train acc: 0.9761
# Epoch 4, step 55, train cls loss: 0.5287, train acc: 0.9759
# Epoch 4, step 60, train cls loss: 0.5270, train acc: 0.9767
# Epoch 4, step 65, train cls loss: 0.5340, train acc: 0.9750
# Epoch 4, step 70, train cls loss: 0.5331, train acc: 0.9753
# Epoch 4, step 75, train cls loss: 0.5275, train acc: 0.9764
# Epoch 4, step 80, train cls loss: 0.5325, train acc: 0.9755
# Epoch 4, step 85, train cls loss: 0.5320, train acc: 0.9757
# Epoch 4, step 90, train cls loss: 0.5350, train acc: 0.9747
# Epoch 4, step 95, train cls loss: 0.5366, train acc: 0.9739
# Epoch 4, step 100, train cls loss: 0.5427, train acc: 0.9720
# Epoch 4, step 105, train cls loss: 0.5531, train acc: 0.9682
# Epoch 4, step 110, train cls loss: 0.5552, train acc: 0.9681
# Epoch 4, step 115, train cls loss: 0.5635, train acc: 0.9662
# Epoch 4, step 120, train cls loss: 0.5604, train acc: 0.9671
# Epoch 4, step 125, train cls loss: 0.5606, train acc: 0.9665
# Epoch 4, step 130, train cls loss: 0.5612, train acc: 0.9666
# Epoch 4, step 135, train cls loss: 0.5704, train acc: 0.9638
# Epoch 4, step 140, train cls loss: 0.5698, train acc: 0.9640
# Epoch 4, step 145, train cls loss: 0.5668, train acc: 0.9649
# Epoch 4, step 150, train cls loss: 0.5666, train acc: 0.9652
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 5, step 5, train cls loss: 0.5300, train acc: 0.9859
# Epoch 5, step 10, train cls loss: 0.5390, train acc: 0.9789
# Epoch 5, step 15, train cls loss: 0.5258, train acc: 0.9802
# Epoch 5, step 20, train cls loss: 0.5608, train acc: 0.9707
# Epoch 5, step 25, train cls loss: 0.5590, train acc: 0.9719
# Epoch 5, step 30, train cls loss: 0.5491, train acc: 0.9727
# Epoch 5, step 35, train cls loss: 0.5397, train acc: 0.9730
# Epoch 5, step 40, train cls loss: 0.5373, train acc: 0.9738
# Epoch 5, step 45, train cls loss: 0.5349, train acc: 0.9752
# Epoch 5, step 50, train cls loss: 0.5303, train acc: 0.9770
# Epoch 5, step 55, train cls loss: 0.5237, train acc: 0.9787
# Epoch 5, step 60, train cls loss: 0.5206, train acc: 0.9793
# Epoch 5, step 65, train cls loss: 0.5180, train acc: 0.9798
# Epoch 5, step 70, train cls loss: 0.5181, train acc: 0.9794
# Epoch 5, step 75, train cls loss: 0.5171, train acc: 0.9796
# Epoch 5, step 80, train cls loss: 0.5137, train acc: 0.9806
# Epoch 5, step 85, train cls loss: 0.5124, train acc: 0.9808
# Epoch 5, step 90, train cls loss: 0.5135, train acc: 0.9807
# Epoch 5, step 95, train cls loss: 0.5128, train acc: 0.9810
# Epoch 5, step 100, train cls loss: 0.5177, train acc: 0.9800
# Epoch 5, step 105, train cls loss: 0.5163, train acc: 0.9806
# Epoch 5, step 110, train cls loss: 0.5217, train acc: 0.9795
# Epoch 5, step 115, train cls loss: 0.5222, train acc: 0.9797
# Epoch 5, step 120, train cls loss: 0.5200, train acc: 0.9802
# Epoch 5, step 125, train cls loss: 0.5209, train acc: 0.9798
# Epoch 5, step 130, train cls loss: 0.5241, train acc: 0.9795
# Epoch 5, step 135, train cls loss: 0.5231, train acc: 0.9797
# Epoch 5, step 140, train cls loss: 0.5227, train acc: 0.9797
# Epoch 5, step 145, train cls loss: 0.5215, train acc: 0.9801
# Epoch 5, step 150, train cls loss: 0.5245, train acc: 0.9786
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 6, step 5, train cls loss: 0.4889, train acc: 0.9922
# Epoch 6, step 10, train cls loss: 0.4964, train acc: 0.9906
# Epoch 6, step 15, train cls loss: 0.4928, train acc: 0.9917
# Epoch 6, step 20, train cls loss: 0.5109, train acc: 0.9844
# Epoch 6, step 25, train cls loss: 0.5132, train acc: 0.9837
# Epoch 6, step 30, train cls loss: 0.5045, train acc: 0.9862
# Epoch 6, step 35, train cls loss: 0.4981, train acc: 0.9882
# Epoch 6, step 40, train cls loss: 0.4941, train acc: 0.9885
# Epoch 6, step 45, train cls loss: 0.4916, train acc: 0.9894
# Epoch 6, step 50, train cls loss: 0.4923, train acc: 0.9891
# Epoch 6, step 55, train cls loss: 0.4912, train acc: 0.9891
# Epoch 6, step 60, train cls loss: 0.4889, train acc: 0.9896
# Epoch 6, step 65, train cls loss: 0.4871, train acc: 0.9900
# Epoch 6, step 70, train cls loss: 0.4967, train acc: 0.9883
# Epoch 6, step 75, train cls loss: 0.4962, train acc: 0.9877
# Epoch 6, step 80, train cls loss: 0.4956, train acc: 0.9876
# Epoch 6, step 85, train cls loss: 0.4942, train acc: 0.9881
# Epoch 6, step 90, train cls loss: 0.4938, train acc: 0.9882
# Epoch 6, step 95, train cls loss: 0.4976, train acc: 0.9869
# Epoch 6, step 100, train cls loss: 0.4968, train acc: 0.9872
# Epoch 6, step 105, train cls loss: 0.4980, train acc: 0.9868
# Epoch 6, step 110, train cls loss: 0.4988, train acc: 0.9863
# Epoch 6, step 115, train cls loss: 0.4991, train acc: 0.9866
# Epoch 6, step 120, train cls loss: 0.5002, train acc: 0.9867
# Epoch 6, step 125, train cls loss: 0.5054, train acc: 0.9852
# Epoch 6, step 130, train cls loss: 0.5047, train acc: 0.9855
# Epoch 6, step 135, train cls loss: 0.5104, train acc: 0.9837
# Epoch 6, step 140, train cls loss: 0.5101, train acc: 0.9841
# Epoch 6, step 145, train cls loss: 0.5104, train acc: 0.9843
# Epoch 6, step 150, train cls loss: 0.5096, train acc: 0.9846
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 7, step 5, train cls loss: 0.4652, train acc: 1.0000
# Epoch 7, step 10, train cls loss: 0.4881, train acc: 0.9930
# Epoch 7, step 15, train cls loss: 0.4827, train acc: 0.9937
# Epoch 7, step 20, train cls loss: 0.4838, train acc: 0.9926
# Epoch 7, step 25, train cls loss: 0.4832, train acc: 0.9922
# Epoch 7, step 30, train cls loss: 0.4830, train acc: 0.9927
# Epoch 7, step 35, train cls loss: 0.4811, train acc: 0.9935
# Epoch 7, step 40, train cls loss: 0.4976, train acc: 0.9896
# Epoch 7, step 45, train cls loss: 0.4961, train acc: 0.9899
# Epoch 7, step 50, train cls loss: 0.4979, train acc: 0.9902
# Epoch 7, step 55, train cls loss: 0.4986, train acc: 0.9896
# Epoch 7, step 60, train cls loss: 0.4982, train acc: 0.9900
# Epoch 7, step 65, train cls loss: 0.5001, train acc: 0.9898
# Epoch 7, step 70, train cls loss: 0.4984, train acc: 0.9898
# Epoch 7, step 75, train cls loss: 0.4987, train acc: 0.9895
# Epoch 7, step 80, train cls loss: 0.4979, train acc: 0.9898
# Epoch 7, step 85, train cls loss: 0.4961, train acc: 0.9903
# Epoch 7, step 90, train cls loss: 0.4943, train acc: 0.9908
# Epoch 7, step 95, train cls loss: 0.4934, train acc: 0.9912
# Epoch 7, step 100, train cls loss: 0.4947, train acc: 0.9905
# Epoch 7, step 105, train cls loss: 0.4949, train acc: 0.9900
# Epoch 7, step 110, train cls loss: 0.4947, train acc: 0.9899
# Epoch 7, step 115, train cls loss: 0.4936, train acc: 0.9903
# Epoch 7, step 120, train cls loss: 0.4924, train acc: 0.9906
# Epoch 7, step 125, train cls loss: 0.4924, train acc: 0.9908
# Epoch 7, step 130, train cls loss: 0.4924, train acc: 0.9909
# Epoch 7, step 135, train cls loss: 0.4925, train acc: 0.9910
# Epoch 7, step 140, train cls loss: 0.4919, train acc: 0.9912
# Epoch 7, step 145, train cls loss: 0.4917, train acc: 0.9913
# Epoch 7, step 150, train cls loss: 0.4910, train acc: 0.9915
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 8, step 5, train cls loss: 0.4743, train acc: 1.0000
# Epoch 8, step 10, train cls loss: 0.4741, train acc: 0.9969
# Epoch 8, step 15, train cls loss: 0.4757, train acc: 0.9964
# Epoch 8, step 20, train cls loss: 0.4715, train acc: 0.9973
# Epoch 8, step 25, train cls loss: 0.4731, train acc: 0.9969
# Epoch 8, step 30, train cls loss: 0.4728, train acc: 0.9971
# Epoch 8, step 35, train cls loss: 0.4793, train acc: 0.9967
# Epoch 8, step 40, train cls loss: 0.4786, train acc: 0.9963
# Epoch 8, step 45, train cls loss: 0.4798, train acc: 0.9958
# Epoch 8, step 50, train cls loss: 0.4797, train acc: 0.9959
# Epoch 8, step 55, train cls loss: 0.4784, train acc: 0.9963
# Epoch 8, step 60, train cls loss: 0.4810, train acc: 0.9956
# Epoch 8, step 65, train cls loss: 0.4818, train acc: 0.9954
# Epoch 8, step 70, train cls loss: 0.4809, train acc: 0.9955
# Epoch 8, step 75, train cls loss: 0.4812, train acc: 0.9956
# Epoch 8, step 80, train cls loss: 0.4803, train acc: 0.9957
# Epoch 8, step 85, train cls loss: 0.4796, train acc: 0.9958
# Epoch 8, step 90, train cls loss: 0.4791, train acc: 0.9959
# Epoch 8, step 95, train cls loss: 0.4808, train acc: 0.9954
# Epoch 8, step 100, train cls loss: 0.4804, train acc: 0.9956
# Epoch 8, step 105, train cls loss: 0.4798, train acc: 0.9958
# Epoch 8, step 110, train cls loss: 0.4794, train acc: 0.9960
# Epoch 8, step 115, train cls loss: 0.4800, train acc: 0.9955
# Epoch 8, step 120, train cls loss: 0.4808, train acc: 0.9951
# Epoch 8, step 125, train cls loss: 0.4806, train acc: 0.9952
# Epoch 8, step 130, train cls loss: 0.4812, train acc: 0.9951
# Epoch 8, step 135, train cls loss: 0.4807, train acc: 0.9953
# Epoch 8, step 140, train cls loss: 0.4803, train acc: 0.9954
# Epoch 8, step 145, train cls loss: 0.4802, train acc: 0.9954
# Epoch 8, step 150, train cls loss: 0.4801, train acc: 0.9955
# ./tfrecord/MCAOS/ref_tf/tf_0.tfrecord
# Epoch 9, step 5, train cls loss: 0.4632, train acc: 1.0000
# Epoch 9, step 10, train cls loss: 0.4667, train acc: 0.9984
# Epoch 9, step 15, train cls loss: 0.4689, train acc: 0.9974
# Epoch 9, step 20, train cls loss: 0.4711, train acc: 0.9977
# Epoch 9, step 25, train cls loss: 0.4721, train acc: 0.9975
# Epoch 9, step 30, train cls loss: 0.4724, train acc: 0.9969
# Epoch 9, step 35, train cls loss: 0.4764, train acc: 0.9962
# Epoch 9, step 40, train cls loss: 0.4762, train acc: 0.9963
# Epoch 9, step 45, train cls loss: 0.4754, train acc: 0.9964
# Epoch 9, step 50, train cls loss: 0.4755, train acc: 0.9966
# Epoch 9, step 55, train cls loss: 0.4746, train acc: 0.9969
# Epoch 9, step 60, train cls loss: 0.4748, train acc: 0.9970
# Epoch 9, step 65, train cls loss: 0.4737, train acc: 0.9972
# Epoch 9, step 70, train cls loss: 0.4741, train acc: 0.9971
# Epoch 9, step 75, train cls loss: 0.4741, train acc: 0.9971
# Epoch 9, step 80, train cls loss: 0.4744, train acc: 0.9972
# Epoch 9, step 85, train cls loss: 0.4744, train acc: 0.9972
# Epoch 9, step 90, train cls loss: 0.4747, train acc: 0.9972
# Epoch 9, step 95, train cls loss: 0.4750, train acc: 0.9971
# Epoch 9, step 100, train cls loss: 0.4752, train acc: 0.9971
# Epoch 9, step 105, train cls loss: 0.4753, train acc: 0.9972
# Epoch 9, step 110, train cls loss: 0.4754, train acc: 0.9972
# Epoch 9, step 115, train cls loss: 0.4764, train acc: 0.9969
# Epoch 9, step 120, train cls loss: 0.4766, train acc: 0.9970
# Epoch 9, step 125, train cls loss: 0.4765, train acc: 0.9971
# Epoch 9, step 130, train cls loss: 0.4771, train acc: 0.9972
# Epoch 9, step 135, train cls loss: 0.4771, train acc: 0.9973
# Epoch 9, step 140, train cls loss: 0.4772, train acc: 0.9973
# Epoch 9, step 145, train cls loss: 0.4770, train acc: 0.9974
# Epoch 9, step 150, train cls loss: 0.4779, train acc: 0.9974
# './weight/MCAOS/'

# %%
# test (only spleen)
weight_path = save_path + f'weight/{exp_id}/'
ref_tf_path = save_path + f'tfrecord/{exp_id}/ref_tf/'
query_tf_path = save_path + f'tfrecord/{exp_id}/query_tf/'

for epoch in [4]:
    results = concerto_test_inter_supervised2(weight_path, ref_tf_path, query_tf_path,
                                             super_parameters = {'batch_size': 64, 'epoch': epoch, 'lr': 1e-5,'drop_rate': 0.1})

    for knn in [10]:
        # NN classifier
        query_neighbor, query_prob = knn_classifier(results['source_feature'],
                                               results['target_feature'],
                                               adata_ref,
                                               adata_ref.obs_names,
                                               column_name=type_key,
                                               k=knn)
        open_score = 1 - query_prob

        kn_data_pr = query_neighbor[shr_mask]
        kn_data_gt = atac_lab[shr_mask]
        kn_data_open_score = open_score[shr_mask]

        unk_data_open_score = open_score[np.logical_not(shr_mask)]

        closed_acc, os_auroc, os_aupr, oscr = osr_evaluator(kn_data_pr, kn_data_gt, kn_data_open_score, unk_data_open_score)
        print(epoch, knn, closed_acc, os_auroc, os_aupr, oscr)
# Out:
# 81173 811
# close_acc= 0.5676
# AUROC= 0.6068
# AUPR= 0.3360
# OSCR= 0.4122
# 4 10 0.5675520733804701 0.6067927379907043 0.3359942725256021 0.41220144831757205

# %% [markdown]
# # Neural classifier

# %%
query_pred, query_prob = results['target_pred'], results['target_prob']

# %%
open_score = 1 - query_prob

kn_data_pr = query_pred[shr_mask]
kn_data_gt = atac_lab[shr_mask]
kn_data_open_score = open_score[shr_mask]

unk_data_open_score = open_score[np.logical_not(shr_mask)]

closed_acc, os_auroc, os_aupr, oscr = osr_evaluator(kn_data_pr, kn_data_gt, kn_data_open_score, unk_data_open_score)
closed_acc, os_auroc, os_aupr, oscr
# Out:
# close_acc= 0.4391
# AUROC= 0.4491
# AUPR= 0.2627
# OSCR= 0.2636
# (0.43913625071660617,
#  0.449138084848685,
#  0.2626566505471447,
#  0.26359141169107553)
